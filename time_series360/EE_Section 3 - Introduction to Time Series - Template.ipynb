# %% [markdown]
# ### Import the Packages

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt 
#import seaborn as sns
#sns.set()

# %% [markdown]
# ### Importing the Data

# %%
raw_csv_data = pd.read_csv('Index2018.csv')

# %%
df_comp = raw_csv_data.copy()

# %% [markdown]
# ### Examining the Data

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df_comp.spx.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Plotting the Data

# %%
import matplotlib.pyplot as plt

# %%
df_comp.spx.plot(title='spx500', figsize = (20,5))

# %%
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp.ftse.plot(title='ftse', figsize=(20,5))

# %%
df_comp.spx.plot(legend=True)
df_comp.ftse.plot(title='ftse vs spx', figsize=(20,5), legend=True)

# %% [markdown]
# ### The QQ Plot

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp.spx, plot=pylab)
pylab.show()

# %%
scipy.stats.probplot(df_comp.ftse, plot=pylab)
# Out:
# ((array([-3.69357572, -3.46171913, -3.33410335, ...,  3.33410335,
#           3.46171913,  3.69357572]),
#   array([2876.6     , 2899.9     , 2909.      , ..., 7762.941268,
#          7769.139189, 7778.637689])),
#  (1126.0991088822118, 5422.713545304514, 0.9825441776412115))
